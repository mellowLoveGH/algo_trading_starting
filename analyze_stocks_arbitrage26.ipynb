# %%
import numpy as np 
import matplotlib.pyplot as plt 
#!pip install yfinance
import yfinance as yf # https://pypi.org/project/yfinance/
import math
import random
import seaborn as sns
import datetime
import pandas as pd
#!pip install sklearn
from sklearn.linear_model import LinearRegression
from scipy import stats
import warnings
warnings.filterwarnings(action='ignore')

# %%
def calculate_week_number(df_data):
    start_weekday = df_data.index[0].weekday()
    start_date = df_data.index[0]
    week_nums = []
    i = 0
    while i<len(df_data.index):
        cur_date = df_data.index[i]
        cur_week_num = ( int((cur_date- start_date).days) + start_weekday ) // 7
        week_nums.append( cur_week_num )
        i += 1
    df_data['week_num'] = week_nums
    return df_data


# get data by ticker-name, start-time & end-time
def get_df_data(ticker_name="AAPL", start_time="2022-01-01", end_time="2022-10-09"):
    df_data = yf.download(tickers=ticker_name, start=start_time, end=end_time) 
    df_data = df_data[ ["Open", "High", "Low", "Close", "Volume"] ]
    df_data['Volume_log'] = np.log2(df_data['Volume'])
    df_data['previous_Close'] = df_data['Close'].shift(1)
    df_data['daily_return'] = (df_data['Close']-df_data['previous_Close'])/df_data['previous_Close']
    df_data['overnight_return'] = (df_data['Open']-df_data['previous_Close'])/df_data['previous_Close']
    MA1, MA2 = 5, 20
    df_data['MA1'] = df_data['Close'].rolling(MA1).mean()
    df_data['MA2'] = df_data['Close'].rolling(MA2).mean()
    df_data['weekday'] = df_data.index.weekday
    df_data = calculate_week_number(df_data)
    return df_data

def merge_stocks(df_data1, df_data2):
    data = []
    i = 0
    while i<len(df_data1):
        target_time = df_data1.index[i]

        j = 0
        while j<len(df_data2):
            ref_time = df_data2.index[j]
            if ref_time>=target_time:
                break
            j += 1
        ref_time = df_data2.index[j-1]
        if ref_time<target_time:
            it1 = df_data1.iloc[i]   
            open1, high1, low1, close1 = it1['Open'], it1['High'], it1['Low'], it1['Close']
            #daily_return1 = it1['daily_return']
            #volume1 = it1['Volume']
            #target_MA1, target_MA2 = it1['MA1'], it1['MA2']
            it2 = df_data2.iloc[j-1]
            open2, high2, low2, close2 = it2['Open'], it2['High'], it2['Low'], it2['Close']
            #daily_return2 = it2['daily_return']
            #volume2 = it2['Volume']
            #ref_MA1, ref_MA2 = it2['MA1'], it2['MA2']

            tmp_list = [ target_time, open1, high1, low1, close1, ref_time, open2, high2, low2, close2 ]
            data.append( tmp_list )
            #print( target_time, ref_time )
        i += 1
    col_names = ['target_time', 'target_open', 'target_high', 'target_low', 'target_close',
                'ref_time', 'ref_open', 'ref_high', 'ref_low', 'ref_close']
    df = pd.DataFrame(data, columns = col_names)
    return df

def get_datasets(merged_data, feature_list=['open', 'close', 'high', 'low'], label="close"):
    features = []
    for f in feature_list:
        tmp_list = list( merged_data['ref_' + f] )
        features.append( tmp_list )
    # pack features
    packed_features = []
    i = 0
    while i<len(features[0]):
        it = []
        j = 0
        while j<len(features):
            v = features[j][i]
            it.append(v)            
            j += 1
        packed_features.append(it)
        i += 1
    labels = merged_data['target_'+label]
    return packed_features, labels

def train_model(train_X, train_y):
    model = LinearRegression().fit(train_X, train_y)

    r_sq = model.score(train_X, train_y)
    print(f"coefficient of determination: {r_sq}")
    print(f"intercept: {model.intercept_}\tslope: {model.coef_}")
    return model

def basic_info(df):
    print("mean:\t", df['dif'].mean())
    print("median:\t", df['dif'].median())
    print("std:\t", df['dif'].std())
    print("25%:\t", df['dif'].quantile(0.25))
    print("50%:\t", df['dif'].quantile(0.50))
    print("75%:\t", df['dif'].quantile(0.75))
    return

def error_analyze(train_y, y_pred, printing=True):
    df = pd.DataFrame(columns = ['y_real', 'y_pred'])
    df['y_real'] = train_y
    df['y_pred'] = y_pred
    df['dif'] = (df['y_real'] - df['y_pred'])/df['y_real'] * 100
    df['dif'] = df['dif'].abs()
    if printing:
        basic_info(df)
    return df

# %%
stocks_info = [
    ('BABA', '9988.HK', 87.79, 1),
    ('BIDU', '9888.HK', 137.69, 1),
    ('JD', '9618.HK', 44.44, 0.5 * 7.8),
    ('MPNGY', '3690.HK', 34.65, 0.5 * 7.8),
    ('NTES', '9999.HK', 77.64, 0.2 * 7.8),
    ('TCOM', '9961.HK', 35.55, 1 * 7.8),
    ('BILI', '9626.HK', 21.57, 1 * 7.8),
    ('LI', '2015.HK', 23.61, 0.5 * 7.8),
    ('NIO', '9866.HK', 9.39, 1 * 7.8),
    ('ZH', '2390.HK', 1.43, 3 * 7.8)
]

OHLC_list = ['open', 'high', 'low', 'close']
daily_prediction = []
daily_real = []

for it in stocks_info[:]: # 
    reference_stock, target_stock, st, ratio = it
    st, et = "2020-01-01", "2023-03-31"
    print("time range:\t", st, "-", et)
    df_data1 = get_df_data(ticker_name=target_stock, start_time=st, end_time=et)
    print("target stock:\t", target_stock, "\t", len(df_data1))
    df_data2 = get_df_data(ticker_name=reference_stock, start_time=st, end_time=et)
    print("reference stock:\t", reference_stock, "\t", len(df_data2))
        # merge reference-stock & target-stock: target stock (datetime, open, high, low, close), 1-day previous reference stock (datetime, open, high, low, close) 
    merged_data = merge_stocks(df_data1, df_data2)
    print("merged_data:\ttarget_time:\t", merged_data.iloc[0]['target_time'], "\t", merged_data.iloc[-1]['target_time'])
    print("merged_data:\tref_time:\t", merged_data.iloc[0]['ref_time'], "\t", merged_data.iloc[-1]['ref_time'])

    stock_name = reference_stock + "_" + target_stock
    
    points = df_data1.iloc[-1]
    daily_real.append( [stock_name, points['Open'], points['High'], points['Low'], points['Close'], points['previous_Close']] )
    
    info_list = [stock_name]

    for label_name in OHLC_list:
        print(label_name)
        #label_name = "high"
        feature_names = ['open', 'high', 'low', 'close'] # 'open', 'high', 'low', 'close'

        n_days = 60

        train_X, train_y = get_datasets(merged_data[-n_days:-1], feature_names, label_name)
        train_X = np.array(train_X)
        train_y = np.array(train_y)

        model = train_model(train_X, train_y)
        y_pred = model.predict(train_X)


        df = error_analyze(train_y, y_pred, False)
        error_mean = df['dif'].mean()


        test_X, test_y = get_datasets(merged_data[-1:], feature_names, label_name)
        test_X = np.array(test_X)
        test_y = np.array(test_y)

        test_y_pred = model.predict(test_X)
        print(f"reference:\t{test_X} \t predicted:\t{test_y_pred}")
        print()
        info_list.append( test_y_pred[0] )
        info_list.append( error_mean )
    daily_prediction.append( info_list )
# Out:
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9988.HK 	 794
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 BABA 	 809
# merged_data:	target_time:	 2020-01-03 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2020-01-02 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9962844545174142
# intercept: 1.6578944073600184	slope: [ 0.05085014 -0.11721045  0.01069462  1.02311367]
# reference:	[[80.15000153 81.90000153 79.48000336 81.        ]] 	 predicted:	[79.85621247]
#
# high
# coefficient of determination: 0.9837786495797953
# intercept: 2.373209487458311	slope: [-0.5624046   0.57508904  0.35516676  0.60506516]
# reference:	[[80.15000153 81.90000153 79.48000336 81.        ]] 	 predicted:	[81.63520602]
#
# low
# coefficient of determination: 0.9868405178016886
# intercept: 3.699737529767873	slope: [-0.34972988  0.23111313  0.39677845  0.65369811]
# reference:	[[80.15000153 81.90000153 79.48000336 81.        ]] 	 predicted:	[79.08255259]
#
# close
# coefficient of determination: 0.9700814354970685
# intercept: 1.8462225614877354	slope: [-0.74604449  0.72655284  0.60153438  0.38096739]
# reference:	[[80.15000153 81.90000153 79.48000336 81.        ]] 	 predicted:	[80.22374705]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9888.HK 	 492
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 BIDU 	 809
# merged_data:	target_time:	 2021-03-23 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2021-03-22 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9839757710718436
# intercept: -4.807614263448329	slope: [0.02937102 0.03308237 0.01464289 0.94075567]
# reference:	[[144.41999817 155.30000305 144.22999573 150.17999268]] 	 predicted:	[147.96646415]
#
# high
# coefficient of determination: 0.892977636249323
# intercept: -3.9361667784582437	slope: [-0.22582744  0.51219788 -0.15321916  0.89208027]
# reference:	[[144.41999817 155.30000305 144.22999573 150.17999268]] 	 predicted:	[154.86797754]
#
# low
# coefficient of determination: 0.9632559988361573
# intercept: 0.05526318907800487	slope: [-0.36716667  0.52555876  0.21650947  0.5823855 ]
# reference:	[[144.41999817 155.30000305 144.22999573 150.17999268]] 	 predicted:	[147.33813973]
#
# close
# coefficient of determination: 0.8674632240956498
# intercept: 1.989124981880252	slope: [-0.46288522  0.79272248  0.12380366  0.50715146]
# reference:	[[144.41999817 155.30000305 144.22999573 150.17999268]] 	 predicted:	[152.26924773]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9618.HK 	 680
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 JD 	 809
# merged_data:	target_time:	 2020-06-18 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2020-06-17 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9942368110508942
# intercept: 3.739064018981594	slope: [ 0.53397439 -1.36681176 -0.44163555  5.13069313]
# reference:	[[38.         39.29999924 37.70000076 38.65999985]] 	 predicted:	[152.0173246]
#
# high
# coefficient of determination: 0.9874145331672431
# intercept: 6.261616211148748	slope: [-0.79010598  0.19232477  1.60507988  2.87596266]
# reference:	[[38.         39.29999924 37.70000076 38.65999985]] 	 predicted:	[155.4921811]
#
# low
# coefficient of determination: 0.9847786994798936
# intercept: 5.143436310916059	slope: [ 0.0777009  -1.02157883  0.92810318  3.78623156]
# reference:	[[38.         39.29999924 37.70000076 38.65999985]] 	 predicted:	[149.31322511]
#
# close
# coefficient of determination: 0.9720527498574739
# intercept: 1.8403032881263357	slope: [-0.78404977  0.07839448  2.76126921  1.85917906]
# reference:	[[38.         39.29999924 37.70000076 38.65999985]] 	 predicted:	[151.10302866]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 3690.HK 	 794
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 MPNGY 	 809
# merged_data:	target_time:	 2020-01-03 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2020-01-02 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9933488723033637
# intercept: 5.483972350889275	slope: [-0.0089234   0.77845954  0.11151918  2.8789033 ]
# reference:	[[32.90000153 33.49000168 32.81999969 33.20000076]] 	 predicted:	[130.50065504]
#
# high
# coefficient of determination: 0.9835235503649529
# intercept: 7.716262784505574	slope: [-0.7647864   2.38474928  0.56909384  1.58067873]
# reference:	[[32.90000153 33.49000168 32.81999969 33.20000076]] 	 predicted:	[133.57624115]
#
# low
# coefficient of determination: 0.974541515248379
# intercept: 9.742986416973793	slope: [0.15815306 2.23335843 0.17750708 0.98452914]
# reference:	[[32.90000153 33.49000168 32.81999969 33.20000076]] 	 predicted:	[128.25355019]
#
# close
# coefficient of determination: 0.9648117436997581
# intercept: 7.572537989287042	slope: [-0.10959583  3.7574425   1.0974208  -1.06775629]
# reference:	[[32.90000153 33.49000168 32.81999969 33.20000076]] 	 predicted:	[130.37143124]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9999.HK 	 685
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 NTES 	 809
# merged_data:	target_time:	 2020-06-11 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2020-06-10 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9800399574746343
# intercept: -4.728091235940042	slope: [ 0.40807642 -0.29409018  0.16062126  1.35853792]
# reference:	[[84.61000061 86.58000183 84.47000122 85.87000275]] 	 predicted:	[134.5622585]
#
# high
# coefficient of determination: 0.944888568596255
# intercept: 3.6454753578901204	slope: [ 0.59618827 -0.81351246  0.28059524  1.51026385]
# reference:	[[84.61000061 86.58000183 84.47000122 85.87000275]] 	 predicted:	[137.0432967]
#
# low
# coefficient of determination: 0.9712190878983329
# intercept: 1.8668385402416021	slope: [ 0.41917203 -1.01583933  0.46630602  1.67342465]
# reference:	[[84.61000061 86.58000183 84.47000122 85.87000275]] 	 predicted:	[132.46746248]
#
# close
# coefficient of determination: 0.9169164790223918
# intercept: 7.422135029258428	slope: [ 0.3199876  -1.13011903  0.84660429  1.47570492]
# reference:	[[84.61000061 86.58000183 84.47000122 85.87000275]] 	 predicted:	[134.88202969]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9961.HK 	 476
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 TCOM 	 809
# merged_data:	target_time:	 2021-04-19 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2021-04-16 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9148685897781459
# intercept: 10.780996673999539	slope: [ 2.98152055 -0.95998302 -1.22001047  6.75799031]
# reference:	[[35.20999908 36.77000046 35.06999969 36.43999863]] 	 predicted:	[283.93714719]
#
# high
# coefficient of determination: 0.8429798816957362
# intercept: 26.409102600189158	slope: [-0.53325894  0.88913037  0.33503272  6.57874182]
# reference:	[[35.20999908 36.77000046 35.06999969 36.43999863]] 	 predicted:	[291.8053203]
#
# low
# coefficient of determination: 0.8567057331093284
# intercept: 29.844122748592042	slope: [-0.56378869 -0.45968985 -0.70319246  8.62836513]
# reference:	[[35.20999908 36.77000046 35.06999969 36.43999863]] 	 predicted:	[282.84698172]
#
# close
# coefficient of determination: 0.7494282556832181
# intercept: 47.317965637300176	slope: [-4.16604839  3.46533486  0.51934799  6.70512383]
# reference:	[[35.20999908 36.77000046 35.06999969 36.43999863]] 	 predicted:	[290.60000725]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9626.HK 	 488
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 BILI 	 809
# merged_data:	target_time:	 2021-03-29 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2021-03-26 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9909892700601172
# intercept: 7.136947963909478	slope: [ 1.25802492 -1.29140586  0.28465023  7.34817992]
# reference:	[[22.64999962 24.04000092 22.54999924 23.62999916]] 	 predicted:	[184.64216169]
#
# high
# coefficient of determination: 0.9634628069516068
# intercept: 16.42559304749571	slope: [-0.18678205 -1.83979334  1.48387524  7.99648345]
# reference:	[[22.64999962 24.04000092 22.54999924 23.62999916]] 	 predicted:	[190.38462895]
#
# low
# coefficient of determination: 0.9696002121773843
# intercept: 10.20163194105902	slope: [-0.09737039 -0.41012067  1.06839103  6.7108874 ]
# reference:	[[22.64999962 24.04000092 22.54999924 23.62999916]] 	 predicted:	[180.80737202]
#
# close
# coefficient of determination: 0.921461144929119
# intercept: 12.819185228678151	slope: [-2.11477335  1.56001136  2.30555336  5.58434884]
# reference:	[[22.64999962 24.04000092 22.54999924 23.62999916]] 	 predicted:	[186.37062929]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 2015.HK 	 396
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 LI 	 664
# merged_data:	target_time:	 2021-08-12 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2021-08-11 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9826774322926285
# intercept: -1.2244320479128703	slope: [0.38768933 0.14911541 0.89786675 2.57207004]
# reference:	[[21.76499939 23.52000046 21.65999985 22.84000015]] 	 predicted:	[88.91469426]
#
# high
# coefficient of determination: 0.9417556524394022
# intercept: 4.006806564917866	slope: [-3.27937306e-03 -1.05634638e+00  1.57779187e+00  3.39758414e+00]
# reference:	[[21.76499939 23.52000046 21.65999985 22.84000015]] 	 predicted:	[90.86595772]
#
# low
# coefficient of determination: 0.9421422887905802
# intercept: 2.255026024108986	slope: [ 1.27902043e+00 -1.86816737e+00  1.20443541e-03  4.36946070e+00]
# reference:	[[21.76499939 23.52000046 21.65999985 22.84000015]] 	 predicted:	[85.97817864]
#
# close
# coefficient of determination: 0.8860402880974215
# intercept: 7.417880063941894	slope: [ 0.2298533  -1.80756797  1.27872463  3.98583037]
# reference:	[[21.76499939 23.52000046 21.65999985 22.84000015]] 	 predicted:	[88.64017887]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 9866.HK 	 254
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 NIO 	 809
# merged_data:	target_time:	 2022-03-10 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2022-03-09 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9848724621696126
# intercept: 2.3326735511330554	slope: [ 2.55349797  0.99153714 -2.03509848  6.04708964]
# reference:	[[8.10000038 9.06000042 8.06999969 8.75      ]] 	 predicted:	[68.48812514]
#
# high
# coefficient of determination: 0.9650096773827113
# intercept: 2.792015936723473	slope: [ 0.40053067 -0.86775792  0.65110138  7.58781928]
# reference:	[[8.10000038 9.06000042 8.06999969 8.75      ]] 	 predicted:	[69.82223398]
#
# low
# coefficient of determination: 0.9740366559993274
# intercept: 3.9722392160095126	slope: [ 0.51850199 -1.07698087  1.70880813  6.20549264]
# reference:	[[8.10000038 9.06000042 8.06999969 8.75      ]] 	 predicted:	[66.50280012]
#
# close
# coefficient of determination: 0.9475321602211928
# intercept: 4.640542356005298	slope: [-0.43815876 -1.49585723  3.2647303   6.15980896]
# reference:	[[8.10000038 9.06000042 8.06999969 8.75      ]] 	 predicted:	[67.78369002]
#
# time range:	 2020-01-01 - 2023-03-31
# [*********************100%***********************]  1 of 1 completed
# target stock:	 2390.HK 	 226
# [*********************100%***********************]  1 of 1 completed
# reference stock:	 ZH 	 499
# merged_data:	target_time:	 2022-04-22 00:00:00 	 2023-03-21 00:00:00
# merged_data:	ref_time:	 2022-04-21 00:00:00 	 2023-03-20 00:00:00
# open
# coefficient of determination: 0.9818977304164135
# intercept: 1.0580819397173542	slope: [1.45296412 6.03943275 3.8147728  3.35359256]
# reference:	[[1.15999997 1.17999995 1.12       1.13      ]] 	 predicted:	[17.93215573]
#
# high
# coefficient of determination: 0.8980472155923159
# intercept: 2.865759631568835	slope: [-8.32423329 16.1426054  -0.47147626  6.03406223]
# reference:	[[1.15999997 1.17999995 1.12       1.13      ]] 	 predicted:	[18.5483597]
#
# low
# coefficient of determination: 0.9647553123926927
# intercept: 2.002504857668761	slope: [0.42690058 1.33848682 3.48013489 8.4421026 ]
# reference:	[[1.15999997 1.17999995 1.12       1.13      ]] 	 predicted:	[17.51445088]
#
# close
# coefficient of determination: 0.906184698680275
# intercept: 3.2862311072521173	slope: [-4.14818125 10.15351724 -0.02982459  6.85589303]
# reference:	[[1.15999997 1.17999995 1.12       1.13      ]] 	 predicted:	[18.16924635]

# %%
###
col_names = ['stock-name', 'open_predicted', 'open_error%', 'high_predicted', 'high_error%', 'low_predicted', 'low_error%', 'close_predicted', 'close_error%']
info_df = pd.DataFrame(daily_prediction, columns=col_names)
info_df

col_names = ['stock-name', 'open', 'high', 'low', 'close', 'previous_Close']
real_df = pd.DataFrame(daily_real, columns=col_names)
real_df['daily_return'] = (real_df['close'] - real_df['previous_Close'])/real_df['previous_Close']*100
real_df

tmp_df = info_df[ ['stock-name', 'close_predicted', 'close_error%'] ].copy()
tmp_df['close_real'] = real_df['close']
tmp_df['dif%'] = (tmp_df['close_predicted'] - tmp_df['close_real'])/tmp_df['close_predicted']*100
tmp_df['dif%'] = tmp_df['dif%'].abs()
tmp_df['Correct'] = tmp_df['close_error%'] > tmp_df['dif%']
tmp_df['daily_return'] = real_df['daily_return'] 
tmp_df
# Out:
#       stock-name  close_predicted  close_error%  close_real      dif%  \
# 0   BABA_9988.HK        80.223747      1.545314   80.500000  0.344353
# 1   BIDU_9888.HK       152.269248      2.163292  148.100006  2.738072
# 2     JD_9618.HK       151.103029      1.705961  150.100006  0.663800
# 3  MPNGY_3690.HK       130.371431      1.763576  130.100006  0.208194
# 4   NTES_9999.HK       134.882030      1.695863  133.000000  1.395315
# 5   TCOM_9961.HK       290.600007      1.434508  291.200012  0.206471
# 6   BILI_9626.HK       186.370629      2.568853  181.000000  2.881693
# 7     LI_2015.HK        88.640179      2.183914   90.400002  1.985355
# 8    NIO_9866.HK        67.783690      1.851279   69.250000  2.163219
# 9     ZH_2390.HK        18.169246      2.810601   18.260000  0.499492
#
#    Correct  daily_return
# 0     True      1.641418
# 1    False      3.205579
# 2     True     -0.199460
# 3     True      0.930964
# 4     True      0.226076
# 5     True      3.482594
# 6    False      6.910807
# 7     True      4.811596
# 8    False      8.798112
# 9     True      0.219544
